# %% [markdown]
# <div class="alert alert-info">
#
# # Positionner des milieux
#
#
# 1. Compléter la fonction `milieu` qui détermine les coordonnées du milieu de 2 points
# 2. Compléter la fonction `next_point` pour qu'elle soit conforme à sa spécification.
# 2. Exécuter le programme et observer ce qu'il produit.
# 3. Expliquer son fonctionnement.
# 4. Comment s'intitule la figure dont le tracé réalisé s'approche ?
#
#  </div>

# %%
from p5 import *

# %%
from random import randint
  
# sommets
A = (0, 400)
B = (400, 400)
C = (200, 0)
point_actuel = A

def milieu(point1, point2):
    '''
    point1 et point2 sont des couples de coordonnées de 2 points dans le plan
    milieu(point1, point2) est le couple des coordonnées du milieu des 2 points.
    '''
    # à compléter
    
def next_point(point):
    '''
    point est un couple de coordonnées
    next_point détermine le milieu entre le point donné et un sommet 
    choisi au hasard parmi A, B et C
    '''
    nb = randint(0, 2)
    if nb == 0:
        point_suivant = ...
    elif nb == 1:
        point_suivant = ...
    else :
        point_suivant = ...
    return ...

def setup():
    # dimension de la fenetre d'affichage
    createCanvas(400, 400)
    # couleur des tracés
    stroke(220, 0, 120)  

def draw():              
    global point_actuel # instruction permettant de redéfinir point_actuel depuis la fonction draw
    point_suivant = next_point(point_actuel)
    circle(point_suivant[0], point_suivant[1], 1)
    point_actuel = point_suivant


run()

# %%
stop()

# %% [markdown]
# <details>
# <summary style="border-left:3px solid #3cb371; border-radius:2pt; width:100%; color:#ffffff; padding:6px; background-color: #66cdaa">
# Réponse
# </summary>
#
# <div style="border-left:3px solid #3cb371; border-radius:2pt; color:#55bc99; padding:6px; background-color: #f7f0eb">
#
#
# Le triangle de Sierpiński : https://fr.wikipedia.org/wiki/Triangle_de_Sierpiński
#
# </div>
# </details>

# %% [markdown]
# <div class="alert alert-info">
#
# # Positionner des centres de gravité
#
#
# 1. Compléter la fonction `centre` qui détermine les coordonnées du centre de gravité de 3 points
# 2. Exécuter le programme et observer ce qu'il produit.
#
#  </div>

# %%
from random import randint
  
# sommets
hexagone = {
'A' : (100,0),
'B' : (300,0),
'C' : (400, 173),
'D' : (300, 346),
'E' : (100, 346),
'F' : (0, 173)
}

point_actuel = hexagone['A']

def centre(point1, point2, point3):
    '''
    point1, point2 et point3 sont des couples de coordonnées de 3 points dans le plan
    centre(point1, point2, point3) est le couple des coordonnées du centre de gravité des 3 points.
    '''
    return ...

def next_point(point):
    '''point est un couple de coordonnées
    next_point détermine le centre d'un triangle formé par le point donné
    et un coté aléatoire de l'hexagone 
    '''
    nb = randint(0,5)
    if nb == 0:
        point_suivant = centre(point, hexagone['A'], hexagone['B'])
    elif nb == 1:
        point_suivant = centre(point, hexagone['B'], hexagone['C'])
    elif nb == 2:
        point_suivant = centre(point, hexagone['C'], hexagone['D'])
    elif nb == 3:
        point_suivant = centre(point, hexagone['D'], hexagone['E'])
    elif nb == 4:
        point_suivant = centre(point, hexagone['E'], hexagone['F'])
    else :
        point_suivant = centre(point, hexagone['F'], hexagone['A'])
    return point_suivant

def setup():           
    # dimension de la fenetre d'affichage
    createCanvas(400, 400)
     # couleur des tracés
    stroke(220, 0, 120)

def draw():            
    global point_actuel
    point_suivant = next_point(point_actuel)
    circle(point_suivant[0], point_suivant[1], 1)
    point_actuel = point_suivant

run()
