# %% [markdown]
# <div class = "alert alert-block alert-danger">
#
# **Noms - prénoms des membres du groupe** :
#
# </div>

# %%
# import de la bibliothèque p5 
from p5 import *

# %% [markdown]
# <div class = "alert alert-block alert-info">
# Le projet suivant permet de mettre en œuvre les connaissances acquises sur les instructions conditionnelles, les booléens, les fonctions.
#
# L'objectif est de créer un élément d'interface graphique comportant trois boutons réactifs au survol et au clic,  à partir des fonctions élémentaires de p5.
# </div>

# %% [markdown]
# ## Généralités sur p5

# %% [markdown]
# <div class = "alert alert-block alert-info">
#
# Les instructions spécifiques à **p5** peuvent être consultées [sur cette page](https://www.carnets.info/jupyter/p5/).
#
# </div>

# %% [markdown]
# ## Étape 1

# %% [markdown]
# <div class = "alert alert-block alert-warning">
#
# ### Cahier des charges :
# - La fenêtre a pour dimensions 300 pixels sur 100.
# - La fenêtre contient trois boutons circulaires alignés, de même dimension.
# - Lorsque la souris ne survole pas la zone rectangulaire qui contient les trois boutons, ceux-ci apparaissent sous la forme de disques gris.
# <img src=https://capytale2.ac-paris.fr/web/sites/default/files/2021-10-16-12-25-35/ac-paris-1/nathalie.weibel/boutons_gris.png width=300>
# - Lorsque la souris survole la zone rectangulaire qui contient les trois boutons, les motifs *play*, *pause* et *stop* apparaissent en gris foncé dans les disques gris.
# <img src=https://capytale2.ac-paris.fr/web/sites/default/files/2021-10-16-12-26-24/ac-paris-1/nathalie.weibel/boutons_gris_motifs.png width=300>
#
#
# </div>

# %%
def setup():
    ...# à compléter

# autres fonctions à créer

def draw():
    ...# à compléter

run()

# %% [markdown]
# ## Étape 2

# %% [markdown]
# <div class = "alert alert-block alert-warning">
#
# ### Cahier des charges :
# - Lorsque la souris survole le disque du bouton *play*, celui-ci apparait en vert et le motif *play* devient blanc.
# <img src=https://capytale2.ac-paris.fr/web/sites/default/files/2021-10-16-12-47-36/ac-paris-1/nathalie.weibel/motif_play_vert.png width=300>
# - Lorsque la souris survole le disque du bouton *pause*, celui-ci apparait en orange et le motif *pause* devient blanc.
# <img src=https://capytale2.ac-paris.fr/web/sites/default/files/2021-10-16-12-47-36/ac-paris-1/nathalie.weibel/motif_pause_orange.png width=300>
#
# - Lorsque la souris survole le disque du bouton *stop*, celui-ci apparait en rouge et le motif *stop* devient blanc.
# <img src=https://capytale2.ac-paris.fr/web/sites/default/files/2021-10-16-12-47-44/ac-paris-1/nathalie.weibel/motif_stop_rouge.png width=300>
#
#
#
# </div>

# %% [markdown]
# ## Étape 3

# %% [markdown]
# <div class = "alert alert-block alert-info">
#
# **p5** comporte une variable système nommée `mouseIsPressed` qui vaut `True` si la souris est cliquée, et `False`
#  sinon.
#
# </div>

# %% [markdown]
# <div class = "alert alert-block alert-warning">
#
# ### Cahier des charges :
# - Lorsque la souris clique sur le disque du bouton *play*, celui-ci s'agrandit et le motif *play* devient vert clair.
# <img src=https://capytale2.ac-paris.fr/web/sites/default/files/2021-10-16-13-03-27/ac-paris-1/nathalie.weibel/motif_play_vert_clique.png width=300>
# - Lorsque la souris clique sur le disque du bouton *pause*, celui-ci s'agrandit et le motif *pause* devient orange foncé.
# <img src=https://capytale2.ac-paris.fr/web/sites/default/files/2021-10-16-13-03-27/ac-paris-1/nathalie.weibel/motif_pause_orange_clique.png width=300>
#
# - Lorsque la souris clique sur le disque du bouton *stop*, celui-ci s'agrandit et le motif *stop* devient rouge foncé.
# <img src=https://capytale2.ac-paris.fr/web/sites/default/files/2021-10-16-13-03-34/ac-paris-1/nathalie.weibel/motif_stop_rouge_clique.png width=300>
#
#
#
# </div>
